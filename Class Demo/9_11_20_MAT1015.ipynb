# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceJulius/FDSFE_GJulius/blob/main/Class%20Demo/9_11_20_MAT1015.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
#initialise our code using a seed if we are using a random function so as to have the same output
np.random.seed(419)
plt.hist(np.random.rand(10));
