# %% [markdown]
# <a href="https://colab.research.google.com/github/GraceJulius/FDSFE_GJulius/blob/main/Class%20Demo/Midterm_review.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
Performance = pd.read_csv("https://raw.githubusercontent.com/fedhere/FDSFE_FBianco/refs/heads/main/StudentPerformanceFactors_modified.csv")
Performance
# Out:
#       Hours_Studied  Attendance Parental_Involvement Access_to_Resources  \
# 0              23.0        84.0                  Low                High
# 1              19.0        64.0                  Low              Medium
# 2              24.0        98.0               Medium              Medium
# 3              29.0        89.0                  Low              Medium
# 4               NaN        92.0               Medium              Medium
# ...             ...         ...                  ...                 ...
# 6602           25.0        69.0                 High              Medium
# 6603           23.0        76.0                 High              Medium
# 6604            NaN        90.0               Medium                 Low
# 6605           10.0        86.0                 High                High
# 6606           15.0        67.0               Medium                 Low
#
#      Extracurricular_Activities  Sleep_Hours  Previous_Scores  \
# ...

# %%
Performance.describe()
# Out:
#        Hours_Studied   Attendance  Sleep_Hours  Previous_Scores  \
# count    6527.000000  6521.000000  6526.000000      6528.000000
# mean       19.984832    79.990799     7.028042        75.067096
# std         5.993324    11.546369     1.469583        14.397116
# min         1.000000    60.000000     4.000000        50.000000
# 25%        16.000000    70.000000     6.000000        63.000000
# 50%        20.000000    80.000000     7.000000        75.000000
# 75%        24.000000    90.000000     8.000000        88.000000
# max        44.000000   100.000000    10.000000       100.000000
#
#        Tutoring_Sessions  Physical_Activity   Exam_Score
# count        6523.000000        6518.000000  6525.000000
# mean            1.493791           2.966247    67.240307
# std             1.231580           1.031094     3.882296
# min             0.000000           0.000000    55.000000
# 25%             1.000000           2.000000    65.000000
# ...

# %%
Performance.shape
# Out:
# (6607, 20)

# %%
Performance.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 20 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Hours_Studied               6527 non-null   float64
#  1   Attendance                  6521 non-null   float64
#  2   Parental_Involvement        6607 non-null   object
#  3   Access_to_Resources         6607 non-null   object
#  4   Extracurricular_Activities  6607 non-null   object
#  5   Sleep_Hours                 6526 non-null   float64
#  6   Previous_Scores             6528 non-null   float64
#  7   Motivation_Level            6607 non-null   object
#  8   Internet_Access             6607 non-null   object
#  9   Tutoring_Sessions           6523 non-null   float64
#  10  Family_Income               6607 non-null   object
#  11  Teacher_Quality             6529 non-null   object
#  12  School_Type                 6607 non-null   object
# ...

# %%
numerical_colNames = ["Hours_Studied", "Attendance", "Sleep_Hours",
                             "Previous_Scores", "Tutoring_Sessions",
                             "Physical_Activity", "Exam_Score"]
numerical_col = Performance[numerical_colNames]
numerical_col
# Out:
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0              23.0        84.0          7.0             73.0
# 1              19.0        64.0          8.0             59.0
# 2              24.0        98.0          7.0             91.0
# 3              29.0        89.0          8.0             98.0
# 4               NaN        92.0          6.0             65.0
# ...             ...         ...          ...              ...
# 6602           25.0        69.0          7.0             76.0
# 6603           23.0        76.0          8.0             81.0
# 6604            NaN        90.0          6.0             65.0
# 6605           10.0        86.0          6.0             91.0
# 6606           15.0        67.0          9.0             94.0
#
#       Tutoring_Sessions  Physical_Activity  Exam_Score
# 0                   0.0                3.0        67.0
# 1                   2.0                4.0        61.0
# ...

# %%
numerical_col.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6607 entries, 0 to 6606
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Hours_Studied      6527 non-null   float64
#  1   Attendance         6521 non-null   float64
#  2   Sleep_Hours        6526 non-null   float64
#  3   Previous_Scores    6528 non-null   float64
#  4   Tutoring_Sessions  6523 non-null   float64
#  5   Physical_Activity  6518 non-null   float64
#  6   Exam_Score         6525 non-null   float64
# dtypes: float64(7)
# memory usage: 361.4 KB

# %%
numerical_colNames = numerical_col.select_dtypes(include=['number']).columns
numerical_colNames
# Out:
# Index(['Hours_Studied', 'Attendance', 'Sleep_Hours', 'Previous_Scores',
#        'Tutoring_Sessions', 'Physical_Activity', 'Exam_Score'],
#       dtype='object')

# %% [markdown]
# looking at missing numbers with msno

# %%
import missingno as msno
msno.matrix(numerical_col)
# Out:
# <Axes: >

# %%
msno.heatmap(numerical_col)
# Out:
# <Axes: >

# %%
numerical_col.fillna(numerical_col.mean(), inplace=True)
numerical_col
# Out:
# <ipython-input-39-cecf29bc2cec>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   numerical_col.fillna(numerical_col.mean(), inplace=True)
#       Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# 0              23.0        84.0          7.0             73.0
# 1              19.0        64.0          8.0             59.0
# 2              24.0        98.0          7.0             91.0
# 3              29.0        89.0          8.0             98.0
# 5              19.0        88.0          8.0             89.0
# ...             ...         ...          ...              ...
# 6600           12.0        98.0          4.0             54.0
# 6602           25.0        69.0          7.0             76.0
# 6603           23.0        76.0          8.0             81.0
# ...

# %%
numerical_col.dropna( inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-38-8fb58394f89c> in <cell line: 1>()
# ----> 1 numerical_col.drop( inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4778                 axes["columns"] = columns
#    4779         else:
# -> 4780             raise ValueError(
#    4781                 "Need to specify at least one of 'labels', 'index' or 'columns'"
#    4782             )
#
# ...

# %%
numerical_col.dshape
# Out:
# (6046, 7)

# %%
msno.matrix(numerical_col)
# Out:
# <Axes: >

# %%
lost = numerical_col.isnull().sum()
lost
# Out:
# Hours_Studied        0
# Attendance           0
# Sleep_Hours          0
# Previous_Scores      0
# Tutoring_Sessions    0
# Physical_Activity    0
# Exam_Score           0
# dtype: int64

# %%
Performance.shape
# Out:
# (6607, 20)

# %%
numerical_col.shape[0]
# Out:
# (6046, 7)

# %%
difference= Performance.shape[0] - numerical_col.shape[0]

# %%
numerical_col.drop( inplace=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-41-bcf865539282> in <cell line: 1>()
# ----> 1 Percentage= difference/Performance.shape[0]*100
#
# NameError: name 'difference' is not defined

# %%
numerical_col.corr()
# Out:
#                    Hours_Studied  Attendance  Sleep_Hours  Previous_Scores  \
# Hours_Studied           1.000000   -0.003900     0.012723         0.024901
# Attendance             -0.003900    1.000000    -0.018557        -0.020674
# Sleep_Hours             0.012723   -0.018557     1.000000        -0.018262
# Previous_Scores         0.024901   -0.020674    -0.018262         1.000000
# Tutoring_Sessions      -0.015869    0.013621    -0.011764        -0.009819
# Physical_Activity       0.004054   -0.023127    -0.002211        -0.003199
# Exam_Score              0.450620    0.584348    -0.015263         0.175748
#
#                    Tutoring_Sessions  Physical_Activity  Exam_Score
# Hours_Studied              -0.015869           0.004054    0.450620
# Attendance                  0.013621          -0.023127    0.584348
# Sleep_Hours                -0.011764          -0.002211   -0.015263
# Previous_Scores            -0.009819          -0.003199    0.175748
# ...

# %%
import pylab as plt
plt.imshow(numerical_col.corr(), clim=(-1,1), cmap="RdBu")
plt.colorbar()
plt.xticks(range(len(numerical_col.columns)), numerical_col.columns, )
plt.yticks(range(len(numerical_col.columns)), numerical_col.columns)

# %%
#distribution of the columns
for c in numerical_col.columns:
  #plt.figure()
    plt.hist(numerical_col[c])
    plt.title(c)
    plt.xlabel(c)
    plt.ylabel("frequency")
    plt.show()

# %%
pd.plotting.scatter_matrix(numerical_col, figsize=(10,10))
# Out:
# array([[<Axes: xlabel='Hours_Studied', ylabel='Hours_Studied'>,
#         <Axes: xlabel='Attendance', ylabel='Hours_Studied'>,
#         <Axes: xlabel='Sleep_Hours', ylabel='Hours_Studied'>,
#         <Axes: xlabel='Previous_Scores', ylabel='Hours_Studied'>,
#         <Axes: xlabel='Tutoring_Sessions', ylabel='Hours_Studied'>,
#         <Axes: xlabel='Physical_Activity', ylabel='Hours_Studied'>,
#         <Axes: xlabel='Exam_Score', ylabel='Hours_Studied'>],
#        [<Axes: xlabel='Hours_Studied', ylabel='Attendance'>,
#         <Axes: xlabel='Attendance', ylabel='Attendance'>,
#         <Axes: xlabel='Sleep_Hours', ylabel='Attendance'>,
#         <Axes: xlabel='Previous_Scores', ylabel='Attendance'>,
#         <Axes: xlabel='Tutoring_Sessions', ylabel='Attendance'>,
#         <Axes: xlabel='Physical_Activity', ylabel='Attendance'>,
#         <Axes: xlabel='Exam_Score', ylabel='Attendance'>],
#        [<Axes: xlabel='Hours_Studied', ylabel='Sleep_Hours'>,
# ...
